# %%
import bw2data as bd
import bw2io as bi
import bw2calc as bc
from copy import deepcopy
import pandas as pd
from pathlib import Path
from bw2io.utils import activity_hash

# %%
# Import lithium LCIs
lci_raw_path = Path("lci-Salar-de-Uyuni.xlsx")

def import_lci_dataset(lci_raw_path, ei_name, bio_name):
    lci = bi.ExcelImporter(lci_raw_path)
    lci.apply_strategies(verbose=False)
    lci.match_database(ei_name, fields=('name', 'reference product', 'unit', 'location'))
    lci.match_database(bio_name, fields=('name', 'unit', 'categories'))
    lci.statistics()
    lci.write_database()
    lci = bd.Database("Salar de Uyuni")
    return lci

# %%
name = "Salar de Uyuni test2"
bio_name = "biosphere3"
ei_name = "ecoinvent 3.9.1 cutoff"

# %%
del bd.databases['Salar de Uyuni']

# %%
bd.projects.set_current(name)

# %%
def import_biosphere(biosphere_f):
    if biosphere_f in bd.databases:
        print(biosphere_f + " database already present!!! No import is needed")
        bio = bd.Database(biosphere_f)
        bio_list = [flow for flow in bio]
        if bio_list == []:
            bi.bw2setup()
        pass
    else:
        bi.bw2setup()
        pass

    bio = bd.Database(biosphere_f)
    return bio

# %%
def import_ecoinvent(ei_path_f, ei_name_f):
    if ei_name_f not in bd.databases:
        ei = bi.SingleOutputEcospold2Importer(ei_path_f, ei_name_f)
        ei.apply_strategies()
        ei.match_database(db_name="biosphere3", fields=('name', 'category', 'unit', 'location'))
        ei.statistics()
        ei.write_database()
    else:
        print(ei_name_f + " database already present!!! No import is needed")
        ei_reg = bd.Database(ei_name_f)
        ei_list = [flow for flow in ei_reg]
        if ei_list == []:
            ei = bi.SingleOutputEcospold2Importer(ei_path_f, ei_name_f)
            ei.apply_strategies()
            ei.match_database(db_name="biosphere3", fields=('name', 'category', 'unit', 'location'))
            ei.statistics()
            ei.write_database()
        pass

    ei_reg = bd.Database(ei_name_f)
    return ei_reg

# %%
import_biosphere(bio_name)
# Out:
# Creating default biosphere
# Writing activities to SQLite3 database:
# Applying strategy: normalize_units
# Applying strategy: drop_unspecified_subcategories
# Applying strategy: ensure_categories_are_tuples
# Applied 3 strategies in 0.01 seconds
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:00
# Title: Writing activities to SQLite3 database:
#   Started: 02/01/2025 15:21:32
#   Finished: 02/01/2025 15:21:33
#   Total time elapsed: 00:00:00
#   CPU %: 97.90
#   Memory %: 1.82
# Created database: biosphere3
# Creating default LCIA methods
#
# Wrote 762 LCIA methods with 227223 characterization factors
# Creating core data migrations
# Brightway2 SQLiteBackend: biosphere3

# %%
ei_path = Path('data/ecoinvent 3.9.1_cutoff_ecoSpold02/datasets')
ei = import_ecoinvent(ei_path, ei_name)
# Out:
# Extracting XML data from 21238 datasets
# Extracted 21238 datasets in 125.18 seconds
# Applying strategy: normalize_units
# Applying strategy: update_ecoinvent_locations
# Applying strategy: remove_zero_amount_coproducts
# Applying strategy: remove_zero_amount_inputs_with_no_activity
# Applying strategy: remove_unnamed_parameters
# Applying strategy: es2_assign_only_product_with_amount_as_reference_product
# Applying strategy: assign_single_product_as_activity
# Applying strategy: create_composite_code
# Applying strategy: drop_unspecified_subcategories
# Applying strategy: fix_ecoinvent_flows_pre35
# Applying strategy: drop_temporary_outdated_biosphere_flows
# Applying strategy: link_biosphere_by_flow_uuid
# Applying strategy: link_internal_technosphere_by_composite_code
# Applying strategy: delete_exchanges_missing_activity
# Applying strategy: delete_ghost_exchanges
# Applying strategy: remove_uncertainty_from_negative_loss_exchanges
# Applying strategy: fix_unreasonably_high_lognormal_uncertainties
# Applying strategy: convert_activity_parameters_to_list
# Applying strategy: add_cpc_classification_from_single_reference_product
# Applying strategy: delete_none_synonyms
# Applying strategy: set_lognormal_loc_value
# Applied 21 strategies in 21.94 seconds
# Applying strategy: link_iterable_by_fields
# Writing activities to SQLite3 database:
# 21238 datasets
# 674593 exchanges
# 0 unlinked exchanges
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:01:36
# Title: Writing activities to SQLite3 database:
#   Started: 02/01/2025 15:26:00
#   Finished: 02/01/2025 15:27:36
#   Total time elapsed: 00:01:36
#   CPU %: 97.60
#   Memory %: 21.58
# Created database: ecoinvent 3.9.1 cutoff

# %%
bio = bd.Database(bio_name)

# %%
# import lithium LCI
lci = import_lci_dataset(lci_raw_path, ei_name, bio_name)
# Out:
# Extracted 1 worksheets in 0.05 seconds
# Applying strategy: link_iterable_by_fields
# Applying strategy: link_iterable_by_fields
# Writing activities to SQLite3 database:
# 18 datasets
# 91 exchanges
# 75 unlinked exchanges
#   Type production: 18 unique unlinked exchanges
#   Type technosphere: 30 unique unlinked exchanges
# ---------------------------------------------------------------------------
# InvalidExchange                           Traceback (most recent call last)
# Cell In[54], line 2
#       1 # import lithium LCI
# ----> 2 lci = import_lci_dataset(lci_raw_path, ei_name, bio_name)
#
# Cell In[51], line 10, in import_lci_dataset(lci_raw_path, ei_name, bio_name)
#       8 lci.match_database(bio_name, fields=('name', 'unit', 'categories'))
#       9 lci.statistics()
# ---> 10 lci.write_database()
#      11 lci = bd.Database("Salar de Uyuni")
#      12 return lci
#
# File ~\Anaconda3\envs\env_BW2\lib\site-packages\bw2io\importers\excel.py:284, in ExcelImporter.write_database(self, **kwargs)
#     282 """Same as base ``write_database`` method, but ``activate_parameters`` is True by default."""
#     283 kwargs["activate_parameters"] = kwargs.get("activate_parameters", True)
# --> 284 super(ExcelImporter, self).write_database(**kwargs)
#
# File ~\Anaconda3\envs\env_BW2\lib\site-packages\bw2io\importers\base_lci.py:269, in LCIImporter.write_database(self, data, delete_existing, backend, activate_parameters, **kwargs)
#     266 self.write_database_parameters(activate_parameters, delete_existing)
#     268 existing.update(data)
# --> 269 db.write(existing)
#     271 if activate_parameters:
#     272     self._write_activity_parameters(activity_parameters)
#
# File ~\Anaconda3\envs\env_BW2\lib\site-packages\bw2data\project.py:358, in writable_project(wrapped, instance, args, kwargs)
#     356 if projects.read_only:
#     357     raise ReadOnlyProject(READ_ONLY_PROJECT)
# --> 358 return wrapped(*args, **kwargs)
#
# File ~\Anaconda3\envs\env_BW2\lib\site-packages\bw2data\backends\peewee\database.py:260, in SQLiteBackend.write(self, data, process)
#     258 if data:
#     259     try:
# --> 260         self._efficient_write_many_data(data)
#     261     except:
#     262         # Purge all data from database, then reraise
#     263         self.delete(warn=False)
#
# File ~\Anaconda3\envs\env_BW2\lib\site-packages\bw2data\backends\peewee\database.py:204, in SQLiteBackend._efficient_write_many_data(self, data, indices)
#     197     self.pbar = pyprind.ProgBar(
#     198         len(data),
#     199         title="Writing activities to SQLite3 database:",
#     200         monitor=True
#     201     )
#     203 for index, (key, ds) in enumerate(data.items()):
# --> 204     exchanges, activities = self._efficient_write_dataset(
#     205         index, key, ds, exchanges, activities
#     206     )
#     208 if not getattr(config, "is_test", None):
#     209     print(self.pbar)
#
# File ~\Anaconda3\envs\env_BW2\lib\site-packages\bw2data\backends\peewee\database.py:156, in SQLiteBackend._efficient_write_dataset(self, index, key, ds, exchanges, activities)
#     154 for exchange in ds.get('exchanges', []):
#     155     if 'input' not in exchange or 'amount' not in exchange:
# --> 156         raise InvalidExchange
#     157     if 'type' not in exchange:
#     158         raise UntypedExchange
#
# InvalidExchange:

# %%
lci

# %%
act = [act for act in lci]
act
# Out:
# [{'amount': 1,
#   'code': 'Water_Uyu',
#   'flow': 'Water_Uyu',
#   'location': 'Salar de Uyuni',
#   'type': 'process',
#   'unit': 'kilogram',
#   'name': 'Water_Uyu',
#   'exchanges': [{'name': 'Water',
#     'amount': 0.00025,
#     'unit': 'cubic meter',
#     'categories': ('air',),
#     'type': 'biosphere',
#     'input': ('biosphere3', '075e433b-4be4-448e-9510-9a5029c1ce94')},
#    {'name': 'Water, unspecified natural origin',
#     'amount': 0.00125,
#     'unit': 'cubic meter',
#     'categories': ('natural resource', 'in ground'),
#     'type': 'biosphere',
#     'input': ('biosphere3', '478e8437-1c21-4032-8438-872a6b5ddcdf')},
#    {'name': 'Water_Uyu',
#     'amount': 1,
#     'location': 'Salar de Uyuni',
#     'unit': 'kilogram',
#     'type': 'production'},
#    {'name': 'market for electricity, high voltage',
#     'amount': 0.007206,
#     'location': 'BO',
#     'unit': 'kilowatt hour',
#     'type': 'technosphere'}],
#   'worksheet name': 'Salar de Uyuni',
#   'database': 'Salar de Uyuni',
#   'reference product': 'Water_Uyu',
#   'production amount': 1},
#  {'amount': 1,
#   'code': 'df_DLE_evaporation_ponds',
#   'flow': 'df_DLE_evaporation_ponds',
#   'location': 'Salar de Uyuni',
#   'type': 'process',
#   'unit': 'kilogram',
#   'name': 'df_DLE_evaporation_ponds',
#   'exchanges': [{'name': 'Occupation, mineral extraction site',
#     'amount': 0,
#     'unit': 'square meter-year',
#     'categories': ('natural resource', 'land'),
#     'type': 'biosphere',
#     'input': ('biosphere3', '379ba5c9-5c3a-43d0-8e2d-605ad9c39e46')},
#    {'name': 'Transformation, from unspecified',
#     'amount': 0,
#     'unit': 'square meter',
#     'categories': ('natural resource', 'land'),
#     'type': 'biosphere',
#     'input': ('biosphere3', '29630a65-f38c-48a5-9744-c0121f586640')},
#    {'name': 'Transformation, to mineral extraction site',
#     'amount': 0,
#     'unit': 'square meter',
#     'categories': ('natural resource', 'land'),
#     'type': 'biosphere',
#     'input': ('biosphere3', '626915e9-2424-4059-8b6a-fae47161acdf')},
#    {'name': 'df_DLE_evaporation_ponds',
#     'amount': 1,
#     'location': 'Salar de Uyuni',
#     'unit': 'kilogram',
#     'type': 'production'},
#    {'name': 'Water_Uyu',
#     'amount': 0.1111111111111111,
#     'location': 'Salar de Uyuni',
#     'unit': 'kilogram',
#     'type': 'technosphere'},
#    {'name': 'df_ion_exchange_L',
#     'amount': 1.111111111111111,
#     'location': 'Salar de Uyuni',
#     'unit': 'kilogram',
#     'type': 'technosphere'},
#    {'name': 'waste_liquid_Uyu',
#     'amount': -0.0001111111111111111,
#     'location': 'Salar de Uyuni',
#     'unit': 'cubic meter',
#     'type': 'technosphere'}],
#   'worksheet name': 'Salar de Uyuni',
#   'database': 'Salar de Uyuni',
#   'reference product': 'df_DLE_evaporation_ponds',
#   'production amount': 1},
#  {'amount': 1,
#   'code': 'df_Li_adsorption',
#   'flow': 'df_Li_adsorption',
#   'location': 'Salar de Uyuni',
#   'type': 'process',
#   'unit': 'kilogram',
#   'name': 'df_Li_adsorption',
#   'exchanges': [{'name': 'df_Li_adsorption',
#     'amount': 1,
#     'location': 'Salar de Uyuni',
#     'unit': 'kilogram',
#     'type': 'production'},
#    {'name': 'df_acidification',
#     'amount': 0.6246870659240872,
#     'location': 'Salar de Uyuni',
#     'unit': 'kilogram',
#     'type': 'technosphere'},
#    {'name': 'heat production, natural gas, at industrial furnace >100kW',
#     'amount': 0,
#     'location': 'Salar de Uyuni',
#     'unit': 'megajoule',
#     'type': 'technosphere'},
#    {'name': 'market for cationic resin',
#     'amount': 0.0006333333333333333,
#     'location': 'RoW',
#     'unit': 'kilogram',
#     'type': 'technosphere'},
#    {'name': 'treatment of waste gypsum, inert material landfill',
#     'amount': -0.0003,
#     'location': 'RoW',
#     'unit': 'kilogram',
#     'type': 'technosphere'}],
#   'worksheet name': 'Salar de Uyuni',
#   'database': 'Salar de Uyuni',
#   'reference product': 'df_Li_adsorption',
#   'production amount': 1},
#  {'amount': 1,
#   'code': 'df_Liprec_BG',
#   'flow': 'df_Liprec_BG',
#   'location': 'Salar de Uyuni',
#   'type': 'process',
#   'unit': 'kilogram',
#   'name': 'df_Liprec_BG',
#   'exchanges': [{'name': 'Heat, waste',
#     'amount': -0.1201441996330882,
#     'unit': 'megajoule',
#     'categories': ('air',),
#     'type': 'biosphere',
#     'input': ('biosphere3', 'f2d84834-d0b3-42e5-b41a-f04cc80337a4')},
#    {'name': 'df_Liprec_BG',
#     'amount': 1,
#     'location': 'Salar de Uyuni',
#     'unit': 'kilogram',
#     'type': 'production'},
#    {'name': 'df_dissolution',
#     'amount': 1.96384915046556,
#     'location': 'Salar de Uyuni',
#     'unit': 'kilogram',
#     'type': 'technosphere'},
#    {'name': 'heat production, natural gas, at industrial furnace >100kW',
#     'amount': 0.9087741261645012,
#     'location': 'Salar de Uyuni',
#     'unit': 'megajoule',
#     'type': 'technosphere'}],
#   'worksheet name': 'Salar de Uyuni',
#   'database': 'Salar de Uyuni',
#   'reference product': 'df_Liprec_BG',
#   'production amount': 1},
#  {'amount': 1,
#   'code': 'df_Liprec_TG',
#   'flow': 'df_Liprec_TG',
#   'location': 'Salar de Uyuni',
#   'type': 'process',
#   'unit': 'kilogram',
#   'name': 'df_Liprec_TG',
#   'exchanges': [{'name': 'df_Liprec_TG',
#     'amount': 1,
#     'location': 'Salar de Uyuni',
#     'unit': 'kilogram',
#     'type': 'production'},
#    {'name': 'Water_Uyu',
#     'amount': 0.02340491080726006,
#     'location': 'Salar de Uyuni',
#     'unit': 'kilogram',
#     'type': 'technosphere'},
#    {'name': 'df_DLE_evaporation_ponds',
#     'amount': 0.970743861490925,
#     'location': 'Salar de Uyuni',
#     'unit': 'kilogram',
#     'type': 'technosphere'},
#    {'name': 'heat production, natural gas, at industrial furnace >100kW',
#     'amount': 0.2693049176424206,
#     'location': 'Salar de Uyuni',
#     'unit': 'megajoule',
#     'type': 'technosphere'},
#    {'name': 'market for soda ash, light',
#     'amount': 0.005851227701815015,
#     'location': 'GLO',
#     'unit': 'kilogram',
#     'type': 'technosphere'}],
#   'worksheet name': 'Salar de Uyuni',
#   'database': 'Salar de Uyuni',
#   'reference product': 'df_Liprec_TG',
#   'production amount': 1},
#  {'amount': 1,
#   'code': 'df_Mg_removal_sodaash',
#   'flow': 'df_Mg_removal_sodaash',
#   'location': 'Salar de Uyuni',
#   'type': 'process',
#   'unit': 'kilogram',
#   'name': 'df_Mg_removal_sodaash',
#   'exchanges': [{'name': 'df_Mg_removal_sodaash',
#     'amount': 1,
#     'location': 'Salar de Uyuni',
#     'unit': 'kilogram',
#     'type': 'production'},
#    {'name': 'df_evaporation_ponds',
#     'amount': 0.7171620784379724,
#     'location': 'Salar de Uyuni',
#     'unit': 'kilogram',
#     'type': 'technosphere'},
#    {'name': 'heat production, natural gas, at industrial furnace >100kW',
#     'amount': 0.1364712118199017,
#     'location': 'Salar de Uyuni',
#     'unit': 'megajoule',
#     'type': 'technosphere'},
#    {'name': 'market for soda ash, light',
#     'amount': 0.05656758431240552,
#     'location': 'GLO',
#     'unit': 'kilogram',
#     'type': 'technosphere'}],
#   'worksheet name': 'Salar de Uyuni',
#   'database': 'Salar de Uyuni',
#   'reference product': 'df_Mg_removal_sodaash',
#   'production amount': 1},
#  {'amount': 1,
#   'code': 'df_acidification',
#   'flow': 'df_acidification',
#   'location': 'Salar de Uyuni',
#   'type': 'process',
#   'unit': 'kilogram',
#   'name': 'df_acidification',
#   'exchanges': [{'name': 'df_acidification',
#     'amount': 1,
#     'location': 'Salar de Uyuni',
#     'unit': 'kilogram',
#     'type': 'production'},
#    {'name': 'df_Mg_removal_sodaash',
#     'amount': 0.9938998963420338,
#     'location': 'Salar de Uyuni',
#     'unit': 'kilogram',
#     'type': 'technosphere'},
#    {'name': 'market for hydrochloric acid, without water, in 30% solution state',
#     'amount': 0.006100103657966163,
#     'location': 'RoW',
#     'unit': 'kilogram',
#     'type': 'technosphere'}],
#   'worksheet name': 'Salar de Uyuni',
#   'database': 'Salar de Uyuni',
#   'reference product': 'df_acidification',
#   'production amount': 1},
#  {'amount': 1,
#   'code': 'df_centrifuge_BG',
#   'flow': 'df_centrifuge_BG',
#   'location': 'Salar de Uyuni',
#   'type': 'process',
#   'unit': 'kilogram',
#   'name': 'df_centrifuge_BG',
#   'exchanges': [{'name': 'df_centrifuge_BG',
#     'amount': 1,
#     'location': 'Salar de Uyuni',
#     'unit': 'kilogram',
#     'type': 'production'},
#    {'name': 'df_Liprec_BG',
#     'amount': 7.716400289835759,
#     'location': 'Salar de Uyuni',
#     'unit': 'kilogram',
#     'type': 'technosphere'},
#    {'name': 'market for electricity, high voltage',
#     'amount': 0.008359433647322072,
#     'location': 'BO',
#     'unit': 'kilowatt hour',
#     'type': 'technosphere'},
#    {'name': 'waste_liquid_Uyu',
#     'amount': -0.006716400289835759,
#     'location': 'Salar de Uyuni',
#     'unit': 'cubic meter',
#     'type': 'technosphere'}],
#   'worksheet name': 'Salar de Uyuni',
#   'database': 'Salar de Uyuni',
#   'reference product': 'df_centrifuge_BG',
#   'production amount': 1},
#  {'amount': 1,
#   'code': 'df_centrifuge_TG',
#   'flow': 'df_centrifuge_TG',
#   'location': 'Salar de Uyuni',
#   'type': 'process',
#   'unit': 'kilogram',
#   'name': 'df_centrifuge_TG',
#   'exchanges': [{'name': 'df_centrifuge_TG',
#     'amount': 1,
#     'location': 'Salar de Uyuni',
#     'unit': 'kilogram',
#     'type': 'production'},
#    {'name': 'df_Liprec_TG',
#     'amount': 212.4652359691973,
#     'location': 'Salar de Uyuni',
#     'unit': 'kilogram',
#     'type': 'technosphere'},
#    {'name': 'market for electricity, high voltage',
#     'amount': 0.2301706722999638,
#     'location': 'BO',
#     'unit': 'kilowatt hour',
#     'type': 'technosphere'},
#    {'name': 'waste_liquid_Uyu',
#     'amount': -0.02114652359691974,
#     'location': 'Salar de Uyuni',
#     'unit': 'cubic meter',
#     'type': 'technosphere'}],
#   'worksheet name': 'Salar de Uyuni',
#   'database': 'Salar de Uyuni',
#   'reference product': 'df_centrifuge_TG',
#   'production amount': 1},
#  {'amount': 1,
#   'code': 'df_centrifuge_wash',
#   'flow': 'df_centrifuge_wash',
#   'location': 'Salar de Uyuni',
#   'type': 'process',
#   'unit': 'kilogram',
#   'name': 'df_centrifuge_wash',
#   'exchanges': [{'name': 'df_centrifuge_wash',
#     'amount': 1,
#     'location': 'Salar de Uyuni',
#     'unit': 'kilogram',
#     'type': 'production'},
#    {'name': 'df_washing_BG',
#     'amount': 2.333333333333333,
#     'location': 'Salar de Uyuni',
#     'unit': 'kilogram',
#     'type': 'technosphere'},
#    {'name': 'market for electricity, high voltage',
#     'amount': 0.002527777777777778,
#     'location': 'BO',
#     'unit': 'kilowatt hour',
#     'type': 'technosphere'},
#    {'name': 'waste_liquid_Uyu',
#     'amount': -0.001333333333333333,
#     'location': 'Salar de Uyuni',
#     'unit': 'cubic meter',
#     'type': 'technosphere'}],
#   'worksheet name': 'Salar de Uyuni',
#   'database': 'Salar de Uyuni',
#   'reference product': 'df_centrifuge_wash',
#   'production amount': 1},
#  {'amount': 1,
#   'code': 'df_dissolution',
#   'flow': 'df_dissolution',
#   'location': 'Salar de Uyuni',
#   'type': 'process',
#   'unit': 'kilogram',
#   'name': 'df_dissolution',
#   'exchanges': [{'name': 'df_dissolution',
#     'amount': 1,
#     'location': 'Salar de Uyuni',
#     'unit': 'kilogram',
#     'type': 'production'},
#    {'name': 'Water_Uyu',
#     'amount': 0.8460236886632826,
#     'location': 'Salar de Uyuni',
#     'unit': 'kilogram',
#     'type': 'technosphere'},
#    {'name': 'df_washing_TG',
#     'amount': 0.1539763113367174,
#     'location': 'Salar de Uyuni',
#     'unit': 'kilogram',
#     'type': 'technosphere'},
#    {'name': 'market for electricity, high voltage',
#     'amount': 0,
#     'location': 'BO',
#     'unit': 'kilowatt hour',
#     'type': 'technosphere'}],
#   'worksheet name': 'Salar de Uyuni',
#   'database': 'Salar de Uyuni',
#   'reference product': 'df_dissolution',
#   'production amount': 1},
#  {'amount': 1,
#   'code': 'df_evaporation_ponds',
#   'flow': 'df_evaporation_ponds',
#   'location': 'Salar de Uyuni',
#   'type': 'process',
#   'unit': 'kilogram',
#   'name': 'df_evaporation_ponds',
#   'exchanges': [{'name': 'Lithium',
#     'amount': 0.0006999999999999999,
#     'unit': 'kilogram',
#     'categories': ('natural resource', 'in ground'),
#     'type': 'biosphere',
#     'input': ('biosphere3', '7d2c1cdd-a64a-5936-a577-5b82db0c0d1b')},
#    {'name': 'Occupation, mineral extraction site',
#     'amount': 0,
#     'unit': 'square meter-year',
#     'categories': ('natural resource', 'land'),
#     'type': 'biosphere',
#     'input': ('biosphere3', '379ba5c9-5c3a-43d0-8e2d-605ad9c39e46')},
#    {'name': 'Transformation, from unspecified',
#     'amount': 0,
#     'unit': 'square meter',
#     'categories': ('natural resource', 'land'),
#     'type': 'biosphere',
#     'input': ('biosphere3', '29630a65-f38c-48a5-9744-c0121f586640')},
#    {'name': 'Transformation, to mineral extraction site',
#     'amount': 0,
#     'unit': 'square meter',
#     'categories': ('natural resource', 'land'),
#     'type': 'biosphere',
#     'input': ('biosphere3', '626915e9-2424-4059-8b6a-fae47161acdf')},
#    {'name': 'Water',
#     'amount': 0,
#     'unit': 'cubic meter',
#     'categories': ('air',),
#     'type': 'biosphere',
#     'input': ('biosphere3', '075e433b-4be4-448e-9510-9a5029c1ce94')},
#    {'name': 'df_evaporation_ponds',
#     'amount': 1,
#     'location': 'Salar de Uyuni',
#     'unit': 'kilogram',
#     'type': 'production'},
#    {'name': 'Water_Uyu',
#     'amount': 0.05,
#     'location': 'Salar de Uyuni',
#     'unit': 'kilogram',
#     'type': 'technosphere'},
#    {'name': 'machine operation, diesel, >= 74.57 kW, high load factor',
#     'amount': 0,
#     'location': 'Salar de Uyuni',
#     'unit': 'hour',
#     'type': 'technosphere'},
#    {'name': 'market for electricity, high voltage',
#     'amount': 0.0001656513157894738,
#     'location': 'BO',
#     'unit': 'kilowatt hour',
#     'type': 'technosphere'},
#    {'name': 'market for quicklime, milled, packed',
#     'amount': 0,
#     'location': 'RoW',
#     'unit': 'kilogram',
#     'type': 'technosphere'},
#    {'name': 'market for sulfuric acid',
#     'amount': 9e-05,
#     'location': 'RoW',
#     'unit': 'kilogram',
#     'type': 'technosphere'},
#    {'name': 'treatment of salt tailing from potash mine, residual material landfill',
#     'amount': 0,
#     'location': 'RoW',
#     'unit': 'kilogram',
#     'type': 'technosphere'},
#    {'name': 'waste_liquid_Uyu',
#     'amount': -5e-05,
#     'location': 'Salar de Uyuni',
#     'unit': 'cubic meter',
#     'type': 'technosphere'}],
#   'worksheet name': 'Salar de Uyuni',
#   'database': 'Salar de Uyuni',
#   'reference product': 'df_evaporation_ponds',
#   'production amount': 1},
#  {'amount': 1,
#   'code': 'df_ion_exchange_L',
#   'flow': 'df_ion_exchange_L',
#   'location': 'Salar de Uyuni',
#   'type': 'process',
#   'unit': 'kilogram',
#   'name': 'df_ion_exchange_L',
#   'exchanges': [{'name': 'Chlorine',
#     'amount': -0.00023,
#     'unit': 'kilogram',
#     'categories': ('water',),
#     'type': 'biosphere',
#     'input': ('biosphere3', 'e8641a14-fd07-4090-8daf-2cce2a557a81')},
#    {'name': 'Heat, waste',
#     'amount': -0.00162,
#     'unit': 'megajoule',
#     'categories': ('air',),
#     'type': 'biosphere',
#     'input': ('biosphere3', 'f2d84834-d0b3-42e5-b41a-f04cc80337a4')},
#    {'name': 'Sodium',
#     'amount': -7.000000000000001e-05,
#     'unit': 'kilogram',
#     'categories': ('water',),
#     'type': 'biosphere',
#     'input': ('biosphere3', '723f56f9-c68e-5692-a969-0fb2a70bce20')},
#    {'name': 'df_ion_exchange_L',
#     'amount': 1,
#     'location': 'Salar de Uyuni',
#     'unit': 'kilogram',
#     'type': 'production'},
#    {'name': 'Water_Uyu',
#     'amount': 0.1375,
#     'location': 'Salar de Uyuni',
#     'unit': 'kilogram',
#     'type': 'technosphere'},
#    {'name': 'df_triple_evaporator',
#     'amount': 1,
#     'location': 'Salar de Uyuni',
#     'unit': 'kilogram',
#     'type': 'technosphere'},
#    {'name': 'market for electricity, high voltage',
#     'amount': 0.0008199999999999999,
#     'location': 'BO',
#     'unit': 'kilowatt hour',
#     'type': 'technosphere'},
#    {'name': 'market for hydrochloric acid, without water, in 30% solution state',
#     'amount': 0.00024,
#     'location': 'RoW',
#     'unit': 'kilogram',
#     'type': 'technosphere'},
#    {'name': 'sodium hydroxide to generic market for neutralising agent',
#     'amount': 0.00012,
#     'location': 'GLO',
#     'unit': 'kilogram',
#     'type': 'technosphere'}],
#   'worksheet name': 'Salar de Uyuni',
#   'database': 'Salar de Uyuni',
#   'reference product': 'df_ion_exchange_L',
#   'production amount': 1},
#  {'amount': 1,
#   'code': 'df_rotary_dryer',
#   'flow': 'df_rotary_dryer',
#   'location': 'Salar de Uyuni',
#   'type': 'process',
#   'unit': 'kilogram',
#   'name': 'df_rotary_dryer',
#   'exchanges': [{'name': 'Heat, waste',
#     'amount': -0.1764705882352941,
#     'unit': 'megajoule',
#     'categories': ('air',),
#     'type': 'biosphere',
#     'input': ('biosphere3', 'f2d84834-d0b3-42e5-b41a-f04cc80337a4')},
#    {'name': 'df_rotary_dryer',
#     'amount': 1,
#     'location': 'Salar de Uyuni',
#     'unit': 'kilogram',
#     'type': 'production'},
#    {'name': 'df_centrifuge_wash',
#     'amount': 1.5,
#     'location': 'Salar de Uyuni',
#     'unit': 'kilogram',
#     'type': 'technosphere'},
#    {'name': 'heat production, natural gas, at industrial furnace >100kW',
#     'amount': 0.3529411764705883,
#     'location': 'Salar de Uyuni',
#     'unit': 'megajoule',
#     'type': 'technosphere'},
#    {'name': 'market for electricity, high voltage',
#     'amount': 1,
#     'location': 'BO',
#     'unit': 'kilowatt hour',
#     'type': 'technosphere'}],
#   'worksheet name': 'Salar de Uyuni',
#   'database': 'Salar de Uyuni',
#   'reference product': 'df_rotary_dryer',
#   'production amount': 1},
#  {'amount': 1,
#   'code': 'df_triple_evaporator',
#   'flow': 'df_triple_evaporator',
#   'location': 'Salar de Uyuni',
#   'type': 'process',
#   'unit': 'kilogram',
#   'name': 'df_triple_evaporator',
#   'exchanges': [{'name': 'df_triple_evaporator',
#     'amount': 1,
#     'location': 'Salar de Uyuni',
#     'unit': 'kilogram',
#     'type': 'production'},
#    {'name': 'df_Li_adsorption',
#     'amount': 2.277,
#     'location': 'Salar de Uyuni',
#     'unit': 'kilogram',
#     'type': 'technosphere'},
#    {'name': 'heat production, natural gas, at industrial furnace >100kW',
#     'amount': 0.1212606657864181,
#     'location': 'Salar de Uyuni',
#     'unit': 'megajoule',
#     'type': 'technosphere'},
#    {'name': 'market for electricity, high voltage',
#     'amount': 0.00333219512195122,
#     'location': 'BO',
#     'unit': 'kilowatt hour',
#     'type': 'technosphere'},
#    {'name': 'market for steam, in chemical industry',
#     'amount': 0.0125,
#     'location': 'RoW',
#     'unit': 'kilogram',
#     'type': 'technosphere'}],
#   'worksheet name': 'Salar de Uyuni',
#   'database': 'Salar de Uyuni',
#   'reference product': 'df_triple_evaporator',
#   'production amount': 1},
#  {'amount': 1,
#   'code': 'df_washing_BG',
#   'flow': 'df_washing_BG',
#   'location': 'Salar de Uyuni',
#   'type': 'process',
#   'unit': 'kilogram',
#   'name': 'df_washing_BG',
#   'exchanges': [{'name': 'df_washing_BG',
#     'amount': 1,
#     'location': 'Salar de Uyuni',
#     'unit': 'kilogram',
#     'type': 'production'},
#    {'name': 'Water_Uyu',
#     'amount': 0.5714285714285714,
#     'location': 'Salar de Uyuni',
#     'unit': 'kilogram',
#     'type': 'technosphere'},
#    {'name': 'df_centrifuge_BG',
#     'amount': 0.4285714285714285,
#     'location': 'Salar de Uyuni',
#     'unit': 'kilogram',
#     'type': 'technosphere'},
#    {'name': 'heat production, natural gas, at industrial furnace >100kW',
#     'amount': 0.2233014133107418,
#     'location': 'Salar de Uyuni',
#     'unit': 'megajoule',
#     'type': 'technosphere'}],
#   'worksheet name': 'Salar de Uyuni',
#   'database': 'Salar de Uyuni',
#   'reference product': 'df_washing_BG',
#   'production amount': 1},
#  {'amount': 1,
#   'code': 'df_washing_TG',
#   'flow': 'df_washing_TG',
#   'location': 'Salar de Uyuni',
#   'type': 'process',
#   'unit': 'kilogram',
#   'name': 'df_washing_TG',
#   'exchanges': [{'name': 'df_washing_TG',
#     'amount': 1,
#     'location': 'Salar de Uyuni',
#     'unit': 'kilogram',
#     'type': 'production'},
#    {'name': 'Water_Uyu',
#     'amount': 0.5714285714285714,
#     'location': 'Salar de Uyuni',
#     'unit': 'kilogram',
#     'type': 'technosphere'},
#    {'name': 'df_centrifuge_TG',
#     'amount': 0.4285714285714285,
#     'location': 'Salar de Uyuni',
#     'unit': 'kilogram',
#     'type': 'technosphere'},
#    {'name': 'heat production, natural gas, at industrial furnace >100kW',
#     'amount': 0.2233014133107418,
#     'location': 'Salar de Uyuni',
#     'unit': 'megajoule',
#     'type': 'technosphere'}],
#   'worksheet name': 'Salar de Uyuni',
#   'database': 'Salar de Uyuni',
#   'reference product': 'df_washing_TG',
#   'production amount': 1},
#  {'amount': 1,
#   'code': 'waste_liquid_Uyu',
#   'flow': 'waste_liquid_Uyu',
#   'location': 'Salar de Uyuni',
#   'type': 'process',
#   'unit': 'cubic meter',
#   'name': 'waste_liquid_Uyu',
#   'exchanges': [{'name': 'Water',
#     'amount': -0.9,
#     'unit': 'cubic meter',
#     'categories': ('air',),
#     'type': 'biosphere',
#     'input': ('biosphere3', '075e433b-4be4-448e-9510-9a5029c1ce94')},
#    {'name': 'waste_liquid_Uyu',
#     'amount': 1,
#     'location': 'Salar de Uyuni',
#     'unit': 'cubic meter',
#     'type': 'production'},
#    {'name': 'market for wastewater, average',
#     'amount': -0.1,
#     'location': 'Salar de Uyuni',
#     'unit': 'cubic meter',
#     'type': 'technosphere'}],
#   'worksheet name': 'Salar de Uyuni',
#   'database': 'Salar de Uyuni',
#   'reference product': 'waste_liquid_Uyu',
#   'production amount': 1}]

# %%
act = [act for act in lci if "rotary_dryer" in act['name']][0]

# %%
def calculate_impacts(activity,methods) :
    """
    Calculate impacts of a given activity and amount using specified methods.

    :param activity: A tuple (database, code) identifying the activity.
    :param amount: Amount of the activity.
    :param methods: List of method tuples to be used for LCA calculations.
    :return: Dictionary of impacts for each method.
    """

    impacts = {}

    for method in methods :
        lca = bc.LCA({activity : 1},method=method)
        lca.lci()
        lca.lcia()
        impacts[method] = lca.score
        print(lca.score)

    return impacts

# %%
del bd.methods['AWARE regionalized']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 del bd.methods['AWARE regionalized']
#
# File ~\Anaconda3\envs\env_BW2\lib\site-packages\bw2data\serialization.py:177, in SerializedDict.__delitem__(self, name)
#     176 def __delitem__(self, name):
# --> 177     del self.data[name]
#     178     self.flush()
#
# KeyError: 'AWARE regionalized'

# %%
def import_aware(ei, bio_f,site_name, site_db, copy_site_db = None):
    new_bio_name = "biosphere water regionalized"

    bio_acts = [act for act in bio_f if "water" in act['name'].lower() and
                ('air' in act['categories'] or 'in air' in act['categories'])]

    if "AWARE regionalized" not in str(bd.methods) :
        plant_classi = ('EcoSpold01Categories', 'agricultural production/plant production')
        ei_loc_list = []
        for act in ei :
            if act.get('location') not in ei_loc_list :
                ei_loc_list.append(act.get('location'))

        ei_loc_list.append(site_name)

        # combine locations with original water biosphere flows
        biosphere_data = {}
        for bio_act in bio_acts :
            for ei_loc in ei_loc_list :
                bio_act_data = deepcopy(bio_act.as_dict())
                bio_act_data['location'] = ei_loc  # Add location
                bio_act_data.pop('database')  # Remove database key
                dbname_code = (new_bio_name, activity_hash(bio_act_data))
                biosphere_data[dbname_code] = bio_act_data
        for bio_act in bio_acts :
            for ei_loc in ei_loc_list :
                bio_act_data = deepcopy(bio_act.as_dict())
                bio_act_data['location'] = ei_loc  # Add location
                bio_act_data.pop('database')  # Remove database key
                bio_act_data['name'] += ', irrigation'
                dbname_code = (new_bio_name, activity_hash(bio_act_data))
                biosphere_data[dbname_code] = bio_act_data

        if new_bio_name in bd.databases :
            print(f"{new_bio_name} database already present!!! No import is needed")
        else :
            new_bio_db = bd.Database(new_bio_name)
            new_bio_db.write(biosphere_data)
            print(f"{new_bio_name} was created.")

        new_bio_db = bd.Database(new_bio_name)

        cf_aware = pd.read_excel(r"data/AWARE_country_regions_Corrected_online_20230113-1.xlsx", engine='openpyxl',
                                 sheet_name='AWARE-annual')
        df_country = pd.read_excel(r"data/Country.xlsx", engine='openpyxl', sheet_name='Sheet1')
        df_country.loc[df_country.Country == "Namibia", "ISO2"] = "NA"

        flows_list = []
        unlinked_loc = []

        for flow in new_bio_db :
            loc_ei = flow.get('location')
            if '-' in loc_ei :
                loc_ei = loc_ei.split('-')[0]
            try :
                loc_aware = df_country.loc[df_country.ISO2 == loc_ei, "AWARE"].iloc[0]
                if 'irrigation' in flow.get('name') :
                    aware_score = cf_aware.loc[cf_aware.Country == loc_aware, "Agg_CF_irri"].iloc[0]
                else :
                    aware_score = cf_aware.loc[cf_aware.Country == loc_aware, "Agg_CF_non_irri"].iloc[0]
                flows_list.append([flow.key, aware_score])
            except :
                try :  # manual match
                    if 'irrigation' in flow.get('name') :
                        aware_score = cf_aware.loc[cf_aware.Ecoinvent_match == flow.get('location'), "Agg_CF_irri"].iloc[0]
                    else :
                        aware_score = \
                        cf_aware.loc[cf_aware.Ecoinvent_match == flow.get('location'), "Agg_CF_non_irri"].iloc[0]
                    flows_list.append([flow.key, aware_score])
                except :
                    if flow.get('location') not in unlinked_loc :
                        unlinked_loc.append(flow.get('location'))
                        print(unlinked_loc)

        # Write new BW method
        aware_tuple = ('AWARE regionalized', 'Annual', 'All')
        aware_method = bd.Method(aware_tuple)
        #new_lcia_method.deregister()  # To delete a method
        data = {
            'unit' : 'm3 world',
            'num_cfs' : len(flows_list),
            'description' : 'xyz',
        }
        # aware_method.deregister()
        aware_method.validate(flows_list)
        aware_method.register()
        aware_method.write(flows_list)

        act_contain_water_list = []
        for act in ei :
            for exc in act.exchanges() :
                if exc.input in bio_acts :
                    act_contain_water_list.append(act)

        for act in site_db :
            print(act)
            for exc in act.exchanges() :
                print(exc)
                if exc.input in bio_acts :
                    act_contain_water_list.append(act)

        if copy_site_db is not None :

            for act in copy_site_db :
                for exc in act.exchanges() :
                    if exc.input in bio_acts :
                        act_contain_water_list.append(act)

        print(f"Number of activities containing water: {len(act_contain_water_list)}")

        agri_act_list = []
        for x in act_contain_water_list :
            for i in x.get('classifications') :
                if i[0] == 'ISIC rev.4 ecoinvent' :
                    if (
                            ('011' in i[1] or '012' in i[1])
                            and '201' not in i[1]
                            and '301' not in i[1]
                    ) :
                        if i[1] not in agri_act_list :
                            agri_act_list.append(i[1])

        for act in act_contain_water_list :
            # check if act is agricultural event
            agri_yes_no = 0
            for classi in act.get('classifications') :
                if classi[1] in agri_act_list :
                    agri_yes_no += 1
                elif classi[1] == 'agricultural production/plant production' :
                    agri_yes_no += 1
            for exc in act.exchanges() :
                if exc.input in bio_acts :
                    flag_replaced = exc.get("replaced with regionalized", False)

                    if not flag_replaced :
                        # Copy data of the existing biosphere activity
                        data = deepcopy(exc.as_dict())
                        #print(data)
                        #print(exc.input['name'], act['name'])
                        try:
                            data.pop('flow')
                        except:
                            pass
                        # Find regionalized biosphere activity from the new biosphere database
                        if agri_yes_no >= 1 :
                            exc_name = exc.input['name'] + ', irrigation'
                            bio_act_regionalized = [
                                bio_act for bio_act in new_bio_db if bio_act['name'] == exc_name
                                                                     and bio_act['categories'] == exc.input['categories']
                                                                     and bio_act['location'] == act['location']
                            ]
                            data['name'] += ', irrigation'
                        else :
                            bio_act_regionalized = [
                                bio_act for bio_act in new_bio_db if bio_act['name'] == exc.input['name']
                                                                     and bio_act['categories'] == exc.input['categories']
                                                                     and bio_act['location'] == act['location']
                            ]
                        assert len(bio_act_regionalized) == 1
                        bio_act_regionalized = bio_act_regionalized[0]
                        # Create new exchange that has all the data from the previous one, except for the input activity
                        # that is now from the new biosphere database
                        data['input'] = (bio_act_regionalized['database'], bio_act_regionalized['code'])
                        act.new_exchange(**data).save()
                        # Set the previous exchange amount to 0, we don't need None location anymore
                        exc['amount'] = 0  # exc.delete()?
                        # Mark that the exchange has been replaced
                        exc['replaced with regionalized'] = True
                        exc.save()

        print(f'AWARE is imported.')
        pass

    else :

        connected_to_biosphere3 = False
        connected_to_biosphere_regionalized = False

        act = [act for act in site_db if f"Water_" in act['name']][0]

        for exc in act.exchanges() :
            database_name = exc.input[0]

            if database_name == 'biosphere3' :

                connected_to_biosphere3 = True
            elif database_name == new_bio_name :

                connected_to_biosphere_regionalized = True
                print(f"{site_db} is already linked to {new_bio_name}.")

        # Now you can check the flags and act accordingly
        if connected_to_biosphere3 :
            new_bio_db = bd.Database(new_bio_name)

            act_contain_water_list = []

            for act in site_db :
                for exc in act.exchanges() :
                    if exc.input in bio_acts :
                        act_contain_water_list.append(act)

            print(f"Number of activities containing water: {len(act_contain_water_list)}")

            agri_act_list = []
            for x in act_contain_water_list :
                for i in x.get('classifications') :
                    if i[0] == 'ISIC rev.4 ecoinvent' :
                        if (
                                ('011' in i[1] or '012' in i[1])
                                and '201' not in i[1]
                                and '301' not in i[1]
                        ) :
                            if i[1] not in agri_act_list :
                                agri_act_list.append(i[1])

            for act in act_contain_water_list :
                # check if act is agricultural event
                agri_yes_no = 0
                for classi in act.get('classifications') :
                    if classi[1] in agri_act_list :
                        agri_yes_no += 1
                    elif classi[1] == 'agricultural production/plant production' :
                        agri_yes_no += 1
                for exc in act.exchanges() :
                    if exc.input in bio_acts :
                        flag_replaced = exc.get("replaced with regionalized", False)

                        if not flag_replaced :
                            # Copy data of the existing biosphere activity
                            data = deepcopy(exc.as_dict())
                            print(data)
                            print(exc.input['name'], act['name'])
                            try :
                                data.pop('flow')
                            except :
                                pass
                            # Find regionalized biosphere activity from the new biosphere database
                            if agri_yes_no >= 1 :
                                exc_name = exc.input['name'] + ', irrigation'
                                bio_act_regionalized = [
                                    bio_act for bio_act in new_bio_db if bio_act['name'] == exc_name
                                                                         and bio_act['categories'] == exc.input[
                                                                             'categories']
                                                                         and bio_act['location'] == act['location']
                                    ]
                                data['name'] += ', irrigation'
                            else :
                                bio_act_regionalized = [
                                    bio_act for bio_act in new_bio_db if bio_act['name'] == exc.input['name']
                                                                         and bio_act['categories'] == exc.input[
                                                                             'categories']
                                                                         and bio_act['location'] == act['location']
                                    ]
                            assert len(bio_act_regionalized) == 1
                            bio_act_regionalized = bio_act_regionalized[0]
                            # Create new exchange that has all the data from the previous one, except for the input activity
                            # that is now from the new biosphere database
                            data['input'] = (bio_act_regionalized['database'], bio_act_regionalized['code'])
                            act.new_exchange(**data).save()
                            # Set the previous exchange amount to 0, we don't need None location anymore
                            exc['amount'] = 0  # exc.delete()?
                            # Mark that the exchange has been replaced
                            exc['replaced with regionalized'] = True
                            exc.save()
            print(f'{site_db} is now linked to {new_bio_name}')
            pass
        elif connected_to_biosphere_regionalized :
            print(f"AWARE regionalized already exists as a method and {site_db} is already linked to {new_bio_name}.")
            pass

# %%
import_aware(ei, bio, "Salar de Uyuni", lci)
# Out:
# Writing activities to SQLite3 database:
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:00
# Title: Writing activities to SQLite3 database:
#   Started: 02/01/2025 15:32:16
#   Finished: 02/01/2025 15:32:17
#   Total time elapsed: 00:00:00
#   CPU %: 89.50
#   Memory %: 18.47
# biosphere water regionalized was created.
# ['RoE']
# {'amount': 1, 'code': 'Water_Uyu', 'flow': 'Water_Uyu', 'location': 'Salar de Uyuni', 'type': 'process', 'unit': 'kilogram', 'name': 'Water_Uyu', 'exchanges': [{'name': 'Water', 'amount': 0.00025, 'unit': 'cubic meter', 'categories': ('air',), 'type': 'biosphere', 'input': ('biosphere3', '075e433b-4be4-448e-9510-9a5029c1ce94')}, {'name': 'Water, unspecified natural origin', 'amount': 0.00125, 'unit': 'cubic meter', 'categories': ('natural resource', 'in ground'), 'type': 'biosphere', 'input': ('biosphere3', '478e8437-1c21-4032-8438-872a6b5ddcdf')}, {'name': 'Water_Uyu', 'amount': 1, 'location': 'Salar de Uyuni', 'unit': 'kilogram', 'type': 'production'}, {'name': 'market for electricity, high voltage', 'amount': 0.007206, 'location': 'BO', 'unit': 'kilowatt hour', 'type': 'technosphere'}], 'worksheet name': 'Salar de Uyuni', 'database': 'Salar de Uyuni', 'reference product': 'Water_Uyu', 'production amount': 1}
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 import_aware(ei, bio, "Salar de Uyuni", lci)
#
# Cell In[44], line 97, in import_aware(ei, bio_f, site_name, site_db, copy_site_db)
#      95 for act in site_db :
#      96     print(act)
# ---> 97     for exc in act.exchanges() :
#      98         print(exc)
#      99         if exc.input in bio_acts :
#
# AttributeError: 'dict' object has no attribute 'exchanges'

# %%
method_cc = [m for m in bd.methods if 'IPCC 2021' in str(m) and 'climate change' in str(m)
                  and 'global warming potential' in str(m)][-20]

method_water = [m for m in bd.methods if "AWARE" in str(m)][0]

method_list = [method_cc, method_water]
